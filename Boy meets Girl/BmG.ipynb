# %%
import pandas as pd

df = pd.read_csv('./data/iris.data.csv', header = None,
                 names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class'])

df.sample(5)
# Out:
#      sepal-length  sepal-width  petal-length  petal-width            class
# 143           6.8          3.2           5.9          2.3   Iris-virginica
# 11            4.8          3.4           1.6          0.2      Iris-setosa
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 88            5.6          3.0           4.1          1.3  Iris-versicolor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal-length    150 non-null float64
# sepal-width     150 non-null float64
# petal-length    150 non-null float64
# petal-width     150 non-null float64
# class           150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
train, test = train_test_split(df, test_size = 0.3)

print(train.shape)
print(test.shape)
# Out:
# (105, 5)
# (45, 5)

# %%
train_X = train[['sepal-length','sepal-width','petal-length','petal-width']]
train_y = train['class']

test_X = test[['sepal-length','sepal-width','petal-length','petal-width']]
test_y = test['class']

# %%
model = DecisionTreeClassifier()

model.fit(train_X, train_y)
prediction = model.predict(test_X)

result = test.copy()
result['class-predicted'] = prediction

# %%
result
# Out:
#      sepal-length  sepal-width  petal-length  petal-width            class  \
# 61            5.9          3.0           4.2          1.5  Iris-versicolor
# 87            6.3          2.3           4.4          1.3  Iris-versicolor
# 13            4.3          3.0           1.1          0.1      Iris-setosa
# 107           7.3          2.9           6.3          1.8   Iris-virginica
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 136           6.3          3.4           5.6          2.4   Iris-virginica
# 80            5.5          2.4           3.8          1.1  Iris-versicolor
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 118           7.7          2.6           6.9          2.3   Iris-virginica
# 126           6.2          2.8           4.8          1.8   Iris-virginica
# 128           6.4          2.8           5.6          2.1   Iris-virginica
# ...

# %%
print('Accuracy:', metrics.accuracy_score(prediction, test_y))
# Out:
# Accuracy: 0.977777777778

# %%
import pickle

pickle.dump(model, open("iris.pkl", "wb"))

# %%
totally_different_model =  pickle.load(open("iris.pkl", "rb"))

prediction = totally_different_model.predict(test_X)
print('Totally Different Accuracy:', metrics.accuracy_score(prediction, test_y))
# Out:
# Totally Different Accuracy: 0.977777777778
